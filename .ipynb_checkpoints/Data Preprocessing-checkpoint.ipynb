# %% [markdown]
# <p style="font-family: Arial; font-size:4.05em; color:darkblue; font-style:bold"><br>
# Intelligent Data Analysis</p><br>

# %% [markdown]
# ## Part II Preprocessing

# %% [markdown]
# Pavol Grofčík
# Dennis Sobolev

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import math
import json as js
import seaborn as sns
import scipy.stats as stats
import re
from sklearn import neighbors
warnings.simplefilter(action='ignore', category=FutureWarning)

# %matplotlib inline

# %% [markdown]
# <p style="font-family: Arial; font-size:2.95em; color:purple; font-style:bold"><br>
# Content</p><br>

# %% [markdown]
# ## Sections
# Analysis of each train dataset is divided into sections, shown below
# * __Introduction__
# * __Personal_train__
#     * Coming soon
#
# * __Other_train__
#     * Also soon

# %% [markdown]
# ## Rozparsovanie JSON [medical info] a vytvorenie nových stĺpcov

# %%
df_other = pd.read_csv("Datasets/other_train.csv", index_col = 0)
df_other.head()
# Out:
#               name                                            address  \
# 0    John Kasprzak            3856 Kayla Track\r\nLake Sara, HI 31241
# 1   Stephen Harvey          34782 Kayla Field\r\nSarahmouth, VT 75984
# 2         Paul Moe                        USNV Mooney\r\nFPO AE 29375
# 3    Sarah Johnson      3633 Bryan Isle\r\nNorth Jamesshire, HI 69484
# 4  Stacy Martinson  65701 Choi Course Apt. 280\r\nNorth Williamton...
#
#   query hyperthyroid FTI measured      education lithium    TT4   T4U  \
# 0                  f            t        HS-grad       f  118.0  1.42
# 1                  f            t        HS-grad       f  112.0  1.03
# 2                  f            t   Some-college       f   87.0  0.96
# 3                  f            t      Doctorate       f  102.0  0.85
# 4                  f            t   Some-college       f  129.0  0.97
#
#    capital-loss  capital-gain ...  hypopituitary  \
# 0           0.0           0.0 ...              f
# ...

# %%
#Funkcia vráti kľúče v danom dictionary
def dictionary_keys(dictionary):
    if (dictionary == None):
        return None
    keys = []
    
    for key in dictionary:
        key = key
        keys.append(key)
        
    return keys

# %%
#Funkcia vráti hodnoty v danom dictionary
def dictionary_values(dictionary):
    if(dictionary == None):
        return None
    values = []
    
    for key in dictionary:
        val = dictionary[key]
        values.append(val)
        
    return values

# %%
#Funkcia rozparsuje json formát
def parse_medical_info(med_info = None):
    
    if(med_info == None):
        return None
    
    med_info = med_info.strip("{}")  #Odstránime {}
    med_info = med_info.split(",")   #Rozdelime na list podľa ","
    
    new = []
    
    for k in med_info:
        a,b = k.split(":")
        new.append(a.strip("'"))
        new.append(b.strip("'"))
        
    final = dict(new[i:i+2] for i in range(0,len(new),2))
    
    #Návratová hodnota je vytvorený slovník
    return final

# %%
#Funkcia vytvorí nové stĺpce v datasete
def add_columns(data = None, json_col = None):
    
    if (data[json_col].empty or json_col == None):
        return None
    
    #Rozparsujeme si prvý row na dict
    dictionary = parse_medical_info(data[json_col][0])
    keys = dictionary_keys(dictionary)
    
    #Vytvorím si nový dataframe a init na np.Nan
    new = pd.DataFrame(columns=keys,index=range(len(data)))
    
    #Iterácia nad dataframe a parsovanie query
    counter = 0
    for json in data[json_col]:
        try:
            if(np.isnan(json)):
                counter += 1
                new.loc[counter] = np.NaN
                continue
        except:
            pass

        json = parse_medical_info(json)
        new.loc[counter] = dictionary_values(json)
        counter += 1

    
    #Odstránim stĺpce z new a pridám ich do pôvodného
    cols = len(new.columns)
    
    for i in range(cols):
        col = new.pop(new.columns[0])
        name = keys[i]

        data[name] = col
    
    
    #Vrátime rozparsovaný dataframe
    return data

# %% [markdown]
# ## Unique identifier

# %%
df_personal = pd.read_csv("Datasets/personal_train.csv", index_col=0)
df_personal.head()
# Out:
#                name                                            address   age  \
# 0       Terry Terry  11818 Lori Crossing Apt. 802\r\nPughstad, DC 7...  68.0
# 1   Edith Boudreaux                 PSC 4657, Box 5446\r\nAPO AP 58412  75.0
# 2      Stephen Lalk                 Unit 9759 Box 9470\r\nDPO AP 45549  67.0
# 3     Abraham Bruce  137 Lewis Flat Suite 762\r\nWest Elizabeth, AL...  34.0
# 4  Janet Washington  995 Frank Stravenue\r\nSouth Matthewport, TX 8...  65.0
#
#   sex date_of_birth
# 0   M    1949-11-16
# 1   F    1943-08-10
# 2   M    1951-05-28
# 3   ?    1984-02-13
# 4   F    1953/06/24

# %%
if ( len(df_personal.name.unique()) != len(df_personal.name)):
    print("Found duplicates")
# Out:
# Found duplicates

# %%
#Concatenating name and address
name = df_personal.name.copy() + " " + df_personal.address.copy()

# %%
if(len(name) != len(name.unique())):
    print("Duplicates!")

# %% [markdown]
# ### Other.csv

# %%
df_other = pd.read_csv("Datasets/other_train.csv", index_col=0)
df_other.head()
# Out:
#               name                                            address  \
# 0    John Kasprzak            3856 Kayla Track\r\nLake Sara, HI 31241
# 1   Stephen Harvey          34782 Kayla Field\r\nSarahmouth, VT 75984
# 2         Paul Moe                        USNV Mooney\r\nFPO AE 29375
# 3    Sarah Johnson      3633 Bryan Isle\r\nNorth Jamesshire, HI 69484
# 4  Stacy Martinson  65701 Choi Course Apt. 280\r\nNorth Williamton...
#
#   query hyperthyroid FTI measured      education lithium    TT4   T4U  \
# 0                  f            t        HS-grad       f  118.0  1.42
# 1                  f            t        HS-grad       f  112.0  1.03
# 2                  f            t   Some-college       f   87.0  0.96
# 3                  f            t      Doctorate       f  102.0  0.85
# 4                  f            t   Some-college       f  129.0  0.97
#
#    capital-loss  capital-gain ...  hypopituitary  \
# 0           0.0           0.0 ...              f
# ...

# %%
other = df_other["name"] + " " + df_other["address"]

# %%
if ( len(df_other.name.unique()) != len(df_other.name)):
    print("Found duplicates")
# Out:
# Found duplicates

# %%
if (len(other) != len(other.unique())):
    print("Still duplicates")
# Out:
# Still duplicates

# %%
#Porovanie df_other a df_personal

# %%
len(df_other.name)
# Out:
# 2287

# %%
len(df_personal.name)
# Out:
# 2237

# %% [markdown]
# ## Merging datasets

# %% [markdown]
# Použili sme funkciu ***merge***
# Je rozdiel, ktorý dataset je ako prvý uvedený, pretože na základe neho sa bude joinovať.

# %%
#Skúška nového joinu
df_new = pd.merge(df_personal, df_other, on=["name", "address"],how="inner", sort = True, copy = True)

# %%
df_new[df_new["name"] == "Flora Jackson"]
# Out:
#               name                                      address   age sex  \
# 754  Flora Jackson  4798 Carter Turnpike\r\nJosemouth, WV 19340  39.0   F
# 755  Flora Jackson  4798 Carter Turnpike\r\nJosemouth, WV 19340  39.0   F
#
#            date_of_birth query hyperthyroid FTI measured education lithium  \
# 754  1979-02-26 00 00 00                  t            t   HS-grad       f
# 755  1979-02-26 00 00 00                  t            t   HS-grad       f
#
#       TT4 ...  hypopituitary  \
# 754  84.0 ...            NaN
# 755  84.0 ...              f
#
#                                           medical_info  \
# 754  {'query hypothyroid':'f','T4U measured':'t','p...
# 755  {'query hypothyroid':'f','T4U measured':'t','p...
#
#      on antithyroid medication referral source  education-num     occupation  \
# 754                          f           other            9.0   Adm-clerical
# 755                        NaN           other            9.0   Adm-clerical
#
# ...

# %%
#Vytvorenie masky na duplikáty
mask = df_new.duplicated(subset=["name", "address"])

# %%
#df_new = df_new[mask == False]

# %%
df_new[df_new["name"] == "Flora Jackson"]
# Out:
#               name                                      address   age sex  \
# 754  Flora Jackson  4798 Carter Turnpike\r\nJosemouth, WV 19340  39.0   F
# 755  Flora Jackson  4798 Carter Turnpike\r\nJosemouth, WV 19340  39.0   F
#
#            date_of_birth query hyperthyroid FTI measured education lithium  \
# 754  1979-02-26 00 00 00                  t            t   HS-grad       f
# 755  1979-02-26 00 00 00                  t            t   HS-grad       f
#
#       TT4 ...  hypopituitary  \
# 754  84.0 ...            NaN
# 755  84.0 ...              f
#
#                                           medical_info  \
# 754  {'query hypothyroid':'f','T4U measured':'t','p...
# 755  {'query hypothyroid':'f','T4U measured':'t','p...
#
#      on antithyroid medication referral source  education-num     occupation  \
# 754                          f           other            9.0   Adm-clerical
# 755                        NaN           other            9.0   Adm-clerical
#
# ...

# %%
#Maska, ktorá obsahuje duplikáty second item
duplicates = df_new[mask == True]

# %%
print("Počet duplikátov: %d" % (len(duplicates)))
# Out:
# Počet duplikátov: 50

# %%
duplicates.head()
# Out:
#                  name                                            address  \
# 44        Alice Stein  910 Peterson Flats Suite 519\r\nSouth Donald, ...
# 101     Angelica Dowd  990 Dana Plaza Apt. 875\r\nLake Maryberg, AZ 7...
# 110     Ann Hernandez  87511 Raven Falls Apt. 369\r\nNew Brian, AZ 19649
# 162      Arlene Smith        574 Shelton Loop\r\nEast Nicholas, KY 33054
# 309  Carmela Respress  656 Stevenson Springs\r\nLake Audreyview, MO 0...
#
#       age sex        date_of_birth query hyperthyroid FTI measured  \
# 44   27.0   F  1991-02-25 00 00 00                  f            t
# 101  20.0   F  1998-02-28 00 00 00                  f            t
# 110  34.0   F           1984-09-05                  f            t
# 162  40.0   F  1978-04-20 00 00 00                  f            t
# 309  68.0   F           1950-01-22                  f          NaN
#
#          education lithium    TT4 ...   hypopituitary  \
# 44    Some-college       f  272.0 ...               f
# ...

# %%
#Určenie indexov na základe ktorých budeme dopĺňať hodnoty
indexes = duplicates.index
print("Pocet duplikatov %d, počet indexov %d" % (len(duplicates), len(indexes)))
# Out:
# Pocet duplikatov 50, počet indexov 50

# %%
#Funkcia, ktorá doplní NaN hodnoty z duplikátov a následne ich odstráni
def fill_from_duplicates(df, duplicates, indexes):
    #indexes = duplicates.indexes
    #mask = df_new.duplicated(subset=["name", "address"])
    #duplicates = df[mask == True]
    
    indexes = indexes.tolist()
    
    #Iterácia nad dataframeomom
    for i in range(0, len(df)):
        if((i+1) == indexes[0]):
            
            #Prechádanie all columns a pre values in [Nan, ?], doplnenie hodnot
            for col in df.columns:
                if (pd.isnull(df.at[i,col]) or df.at[i,col] == "?"):
                    df.at[i,col] = df.at[i+1,col]
            
            indexes.pop(0)
            df.drop(i+1, inplace = True)
            if(len(indexes) == 0):
                #Zresetujeme index
                df_new.reset_index(drop=True,inplace=True)
                print("Done")
                break

# %%
fill_from_duplicates(df_new, duplicates, indexes)
# Out:
# Done

# %%
duplicates.head()
# Out:
#                  name                                            address  \
# 44        Alice Stein  910 Peterson Flats Suite 519\r\nSouth Donald, ...
# 101     Angelica Dowd  990 Dana Plaza Apt. 875\r\nLake Maryberg, AZ 7...
# 110     Ann Hernandez  87511 Raven Falls Apt. 369\r\nNew Brian, AZ 19649
# 162      Arlene Smith        574 Shelton Loop\r\nEast Nicholas, KY 33054
# 309  Carmela Respress  656 Stevenson Springs\r\nLake Audreyview, MO 0...
#
#       age sex        date_of_birth query hyperthyroid FTI measured  \
# 44   27.0   F  1991-02-25 00 00 00                  f            t
# 101  20.0   F  1998-02-28 00 00 00                  f            t
# 110  34.0   F           1984-09-05                  f            t
# 162  40.0   F  1978-04-20 00 00 00                  f            t
# 309  68.0   F           1950-01-22                  f          NaN
#
#          education lithium    TT4 ...   hypopituitary  \
# 44    Some-college       f  272.0 ...               f
# ...

# %%
df_new.head(45)
# Out:
#                    name                                            address  \
# 0        Aaron Johansen  744 Sandoval Causeway\r\nEast Robertburgh, NC ...
# 1      Abigail Martinez         59351 Craig Courts\r\nGordonbury, WI 53797
# 2         Abraham Bruce  137 Lewis Flat Suite 762\r\nWest Elizabeth, AL...
# 3         Abraham Hicks    031 Wood Wall Apt. 152\r\nVictorburgh, CA 40253
# 4          Ada Jeffries        66827 Ortiz Radial\r\nWest Justin, IL 04779
# 5             Ada Wells           906 Booth Mews\r\nJohnsonmouth, IL 11134
# 6         Adam Wolfgram    54641 Ritter Park\r\nPort Darlenefort, GA 55617
# 7         Adam Zabinski  3914 Nicholas Station Suite 166\r\nSouth David...
# 8         Addie Taggart  2136 Laura Drives Suite 251\r\nLaneland, NC 10613
# 9       Adrian Carvalho   7320 Jennifer River Apt. 801\r\nMayton, SD 19987
# 10        Adriana Terry                 PSC 3262, Box 5006\r\nAPO AA 55265
# ...

# %%
df_other= add_columns(data=df_other,json_col="medical_info")
df_other[df_other.columns[15:]].head()
# Out:
#      relationship sick workclass TT4 measured  \
# 0         Husband    f   Private            t
# 1   Not-in-family    f       NaN            t
# 2         Husband    f   Private            t
# 3   Not-in-family    f        ??            t
# 4       Own-child    f   Private            t
#
#                              class       marital-status goitre  \
# 0  increased binding protein.|2384   Married-civ-spouse      f
# 1                    negative.|358        Never-married      f
# 2                   negative.|1247   Married-civ-spouse      f
# 3                   negative.|1829        Never-married      f
# 4                   negative.|3531        Never-married      f
#
#    native-country hypopituitary  \
# 0   United-States             f
# 1   United-States             f
# 2   United-States             f
# 3   United-States             f
# 4   United-States             f
#
#                                         medical_info  ...  query hypothyroid  \
# ...

# %% [markdown]
# ## Kontrola duplikátov

# %%
df_new[df_new.name == "Ann Hernandez"]
# Out:
#               name                                            address   age  \
# 107  Ann Hernandez  87511 Raven Falls Apt. 369\r\nNew Brian, AZ 19649  34.0
#
#     sex date_of_birth query hyperthyroid FTI measured   education lithium  \
# 107   F    1984-09-05                  f            t   Bachelors       f
#
#       TT4 ...  hypopituitary  \
# 107  96.0 ...              f
#
#                                           medical_info  \
# 107  {'query hypothyroid':'f','T4U measured':'t','p...
#
#      on antithyroid medication referral source  education-num     occupation  \
# 107                          f           other        -1300.0   Adm-clerical
#
#      TBG measured  TBG    race FTI
# 107             f  NaN   Black  90
#
# [1 rows x 36 columns]

# %% [markdown]
# ## Po deduplikovaní - rozparsujeme "medical info"

# %%
df_new = add_columns(data=df_new,json_col="medical_info")

# %%
df_new[df_new.columns[15:]].head()
# Out:
#     T3    fnlwgt  hours-per-week    relationship sick          workclass  \
# 0  2.0  240810.0            45.0         Husband    f            private
# 1  3.0   55743.0            45.0            Wife    f            Private
# 2  2.0  193868.0            50.0   Not-in-family    f       Self-emp-inc
# 3  1.6  119069.0            40.0         Husband    f   Self-emp-not-inc
# 4  1.8  195189.0            40.0       Unmarried    f            Private
#
#   TT4 measured                            class       marital-status goitre  \
# 0            t                    negative.|511   Married-civ-spouse      f
# 1            t  increased binding protein.|1799   Married-civ-spouse      f
# 2            t                   negative._2741        Never-married      f
# 3            t                    negative.|542   Married-civ-spouse      f
# 4            t                     negative.|72             Divorced      f
#
# ...

# %% [markdown]
# ## Následne znoramalizujeme hodnoty podľa analýzy

# %% [markdown]
# Preprocessing a **class** column

# %%
df_new["class"].head()
# Out:
# 0                      negative.|511
# 1    increased binding protein.|1799
# 2                     negative._2741
# 3                      negative.|542
# 4                       negative.|72
# Name: class, dtype: object

# %%
df_new["class"] = df_new["class"].str.replace("_","")
df_new["class"] = df_new["class"].str.replace("|","")
df_new["class"].head()
# Out:
# 0                      negative.511
# 1    increased binding protein.1799
# 2                     negative.2741
# 3                      negative.542
# 4                       negative.72
# Name: class, dtype: object

# %%
df_new[["class", "class_protein"]] = df_new["class"].str.split(".",expand = True)
df_new[["class", "class_protein"]].head()
# Out:
#                        class class_protein
# 0                   negative           511
# 1  increased binding protein          1799
# 2                   negative          2741
# 3                   negative           542
# 4                   negative            72

# %% [markdown]
# ## Preprocessing a education num column - dealing with outliers

# %%
stats = df_new["education-num"].describe()
stats
# Out:
# count    2236.000000
# mean        9.508945
# std       329.903813
# min     -1600.000000
# 25%         9.000000
# 50%        10.000000
# 75%        12.000000
# max      1400.000000
# Name: education-num, dtype: float64

# %%
sns.boxplot(stats)

# %%
#Pôvôdné hodnoty
sns.distplot(stats)

# %% [markdown]
# Odstránenie outliers pomocou ***normálizácie 5% a 95 %**

# %%
#Funkcia na normalizáciu
def normalize(data):
    q1 = data.quantile(0.05) - 1.5 * stats.iqr(data)
    q2 = data.quantile(0.95) + 1.5 * stats.iqr(data)
    
    #We return filter
    return data[(data > q1) & (data < q2)]

# %% [markdown]
# ## Normalizácia hodnôt na jednotný formát

# %% [markdown]
# ### Pohlavie '?'

# %%
df_new.sex.value_counts()
# Out:
# F    1448
# M     701
# ?      88
# Name: sex, dtype: int64

# %% [markdown]
# ### Skript na normálizáciu rôznych hodnôt na jednotný formát

# %%
uniq = df_new["on antithyroid medication"].unique().tolist()
uniq
# Out:
# ['f', 'FALSE', 'F', 't', 'TRUE', 'T', 'f.2']

# %%
all_vals = uniq.copy()

# %%
#Porovnanie na základe hodnoty
all_vals == uniq
# Out:
# True

# %%
#Porovnanie na základe adresy
all_vals is uniq
# Out:
# False

# %%
df_new["on antithyroid medication"].unique()
# Out:
# array(['f', 'FALSE', 'F', 't', 'TRUE', 'T', 'f.2'], dtype=object)

# %%
#Funkcia na normalizáciu skriptov
def normalize_identifiers(data, column):
    """Skrit znormalizuje hodnoty daného stĺpca podľa prvého znaku
    Napríklad f,f.2 -> f
    Nie je vhodný ak stĺpec obsahuje NaN values
    """
    if(data[column].isna().any()):
        new_col = data[column].copy()
        
        for i in range(0,len(new_col)):
            if(pd.isna(new_col.iloc[i])):
                continue
            else:
                new_col.iloc[i] = new_col.iloc[i].lower()[0]
        data[column] = new_col.copy()
    else:
        data[column] = data[column].apply(lambda x : x.lower())
        data[column] = data[column].apply(lambda x :  x.replace(x,x[0]))
        data[data[column] == 'n'][column] = np.nan

# %%
normalize_identifiers(df_new, "on antithyroid medication")

# %%
df_new["on antithyroid medication"].unique()
# Out:
# array(['f', 't'], dtype=object)

# %% [markdown]
# ## Skript na nahradenie NaN values mean/med/mod
# Len pre numerické atribúty

# %%
df_new[np.isnan(df_new["TT4"]) == False]
# Out:
#                      name                                            address  \
# 0          Aaron Johansen  744 Sandoval Causeway\r\nEast Robertburgh, NC ...
# 1        Abigail Martinez         59351 Craig Courts\r\nGordonbury, WI 53797
# 2           Abraham Bruce  137 Lewis Flat Suite 762\r\nWest Elizabeth, AL...
# 3           Abraham Hicks    031 Wood Wall Apt. 152\r\nVictorburgh, CA 40253
# 4            Ada Jeffries        66827 Ortiz Radial\r\nWest Justin, IL 04779
# 6           Adam Wolfgram    54641 Ritter Park\r\nPort Darlenefort, GA 55617
# 7           Adam Zabinski  3914 Nicholas Station Suite 166\r\nSouth David...
# 8           Addie Taggart  2136 Laura Drives Suite 251\r\nLaneland, NC 10613
# 9         Adrian Carvalho   7320 Jennifer River Apt. 801\r\nMayton, SD 19987
# 10          Adriana Terry                 PSC 3262, Box 5006\r\nAPO AA 55265
# 11          Adrienne Bush  29598 Carter Ferry Suite 258\r\nWest Nicolelan...
# ...

# %%
def fill_numeric_miss_values(data,column,method):
    """Funkcia na nahradenie chýbajúcich hodnôt
    na základe zvolenej metódy
    Method = [med,mod,mean]"""
    
    methods = ["mean","med","mod"]
    
    if (data[column].isna().any() == False):
        #Stĺpec neobsahuje žiadne NaN hodnoty
        print("No missing values!")
        return
    
    #Vytvorenie masky pre Nan values
    mask = data[column].isna()
    
    #Kontrola metódy
    if(method not in methods):
        print("Nespravne zvolená metóda")
        return
    
    #Určenie hodnoty na nahradenie NaN
    if (method == "mean"):
        col = data[column]
        col = col[mask == False]
        value = np.mean(col)
        print(str.upper(method)," Value is:", value)
        
    elif (method == "med"):
        col = data[column]
        col = col[mask == False]
        value = col.mean()
        print(str.upper(method)," Value is:", value)

    elif (method == "mod"):
        col = data[column]
        col = col[mask == False]
        value = col.mode()[0]
        print(str.upper(method)," Value is:", value)

    #Nahradenie hodnotou
    new_col = data[column].copy()
    for i in range(0,len(new_col)):

        if(pd.isna(new_col.iloc[i])):
            new_col.iloc[i] = value
   
    data[column] = new_col.copy()
    data[column] = data[column].astype("float64")
    
    print("Filling missing values by %s done!" % (str.upper(method)))

# %%
fill_numeric_miss_values(df_new,"TT4", method="mean")
# Out:
# MEAN  Value is: 109.32809956917185
# Filling missing values by MEAN done!

# %% [markdown]
# ## Normalizácia hodnôt v stĺpcoch automaticky

# %%
def normalize_columns_booleans(data):
    
    """ Funkcia znormalizuje stĺpce dataframe = data
        pre stĺpce, ktoré obsahujú hodnoty t/f a iné t.8,f.2....
        na hodnoty t/f
        Funkcia nenahradzuje Nan values
    """
    
    #Prechádzanie po stĺpcoch
    for col in df_new.columns:
  
        a = pd.unique(df_new[col])

        flags = ["f","t", "t.[0-9]", "f.[0-9]"]

        for item in a:

            #Znormalizujeme hodnoty
            if(item in flags):
                normalize_identifiers(data=data,column=col)
                print("Normalized %s" % (col))
                break

# %%
normalize_columns_booleans(data=df_new)
# Out:
# Normalized query hyperthyroid
# Normalized FTI measured
# Normalized lithium
# Normalized tumor
# Normalized sick
# Normalized TT4 measured
# Normalized goitre
# Normalized hypopituitary
# Normalized on antithyroid medication
# Normalized TBG measured
# Normalized query hypothyroid
# Normalized T4U measured
# Normalized pregnant
# Normalized thyroid surgery
# Normalized TSH measured
# Normalized query on thyroxine
# Normalized I131 treatment
# Normalized on thyroxine
# Normalized T3 measured
# Normalized psych

# %% [markdown]
# ## Manuálne prechádzanie po stĺpcoch manuálne

# %%
normalize_identifiers(data=df_new, column="sick")

# %%
df_new["hypopituitary"].unique()
# Out:
# array(['f'], dtype=object)

# %%
normalize_identifiers(data=df_new, column="hypopituitary")

# %%
df_new["TBG measured"].unique()
# Out:
# array(['f'], dtype=object)

# %%
df_new["TBG measured"].unique()
normalize_identifiers(data=df_new, column="TBG measured")

# %%
df_new["tumor"].unique()
# Out:
# array(['f', 't'], dtype=object)

# %%
normalize_identifiers(data=df_new, column="tumor")

# %%
df_new["sick"].unique()
# Out:
# array(['f', 't'], dtype=object)

# %%
print(df_new["query hyperthyroid"].unique())
normalize_identifiers(data=df_new, column="query hyperthyroid")
print(df_new["query hyperthyroid"].unique())
# Out:
# ['f' 't' 'f.8']

# %%
print(df_new["FTI measured"].unique())
normalize_identifiers(data=df_new, column="FTI measured")
print(df_new["FTI measured"].unique())
# Out:
# ['t' 'f' 't.4']
# ['t' 'f']

# %%
print(df_new["lithium"].unique())
normalize_identifiers(data=df_new, column="lithium")
print(df_new["lithium"].unique())
# Out:
# ['f' 't' 'f.9']
# ['f' 't']

# %%
print(df_new["TT4 measured"].unique())
normalize_identifiers(data=df_new, column="TT4 measured")
print(df_new["TT4 measured"].unique())
# Out:
# ['t' 'f' 't.2']
# ['t' 'f']

# %%
print(df_new["goitre"].unique())
normalize_identifiers(data=df_new, column="goitre")
print(df_new["goitre"].unique())
# Out:
# ['f' 't' 'f.10']
# ['f' 't']

# %%
print(df_new["T4U measured"].unique())
normalize_identifiers(data=df_new, column="T4U measured")
print(df_new["T4U measured"].unique())
# Out:
# ['t' 'f' nan 't.3']
# ['t' 'f' nan]

# %%
print(df_new["pregnant"].unique())
normalize_identifiers(data=df_new, column="pregnant")
print(df_new["pregnant"].unique())
# Out:
# ['f' 't' nan 'f.4']
# ['f' 't' nan]

# %%
print(df_new["thyroid surgery"].unique())
normalize_identifiers(data=df_new, column="thyroid surgery")
print(df_new["thyroid surgery"].unique())
# Out:
# ['f' 't' nan 'f.5']
# ['f' 't' nan]

# %%
print(df_new["query on thyroxine"].unique())
normalize_identifiers(data=df_new, column="query on thyroxine")
print(df_new["query on thyroxine"].unique())
# Out:
# ['f' 't' nan 'f.1']
# ['f' 't' nan]

# %%
print(df_new["I131 treatment"].unique())
normalize_identifiers(data=df_new, column="I131 treatment")
print(df_new["I131 treatment"].unique())
# Out:
# ['f' 't' nan 'f.6']
# ['f' 't' nan]

# %%
print(df_new["T3 measured"].unique())
normalize_identifiers(data=df_new, column="T3 measured")
print(df_new["T3 measured"].unique())
# Out:
# ['t' 'f' nan 't.1']
# ['t' 'f' nan]

# %%
print(df_new["psych"].unique())
normalize_identifiers(data=df_new, column="psych")
print(df_new["psych"].unique())
# Out:
# ['f' 't' nan 'f.13']
# ['f' 't' nan]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2237 entries, 0 to 2236
# Data columns (total 47 columns):
# name                         2237 non-null object
# address                      2237 non-null object
# age                          2236 non-null float64
# sex                          2237 non-null object
# date_of_birth                2236 non-null object
# query hyperthyroid           2237 non-null object
# FTI measured                 2237 non-null object
# education                    2237 non-null object
# lithium                      2237 non-null object
# TT4                          2237 non-null float64
# T4U                          2002 non-null float64
# capital-loss                 2012 non-null float64
# capital-gain                 2237 non-null float64
# tumor                        2237 non-null object
# TSH                          2005 non-null float64
# T3                           2237 non-null float64
# ...

# %% [markdown]
# ## K nearest neighbour classifier

# %%
df_new["TSH"].isna().any()
# Out:
# True

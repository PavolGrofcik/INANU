# %% [markdown]
# <p style="font-family: Arial; font-size:4.05em; color:darkblue; font-style:bold"><br>
# Intelligent Data Analysis</p><br>

# %% [markdown]
# ## Part II Preprocessing

# %% [markdown]
# Pavol Grofčík
# Dennis Sobolev

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import math
import json as js
warnings.simplefilter(action='ignore', category=FutureWarning)

# %matplotlib inline

# %% [markdown]
# <p style="font-family: Arial; font-size:2.95em; color:purple; font-style:bold"><br>
# Content</p><br>

# %% [markdown]
# ## Sections
# Analysis of each train dataset is divided into sections, shown below
# * __Introduction__
# * __Personal_train__
#     * Coming soon
#
# * __Other_train__
#     * Also soon

# %% [markdown]
# ## Rozparsovanie JSON [medical info] a vytvorenie nových stĺpcov

# %%
df_other = pd.read_csv("Datasets/other_train.csv", index_col = 0)
df_other.head()
# Out:
#               name                                            address  \
# 0    John Kasprzak            3856 Kayla Track\r\nLake Sara, HI 31241
# 1   Stephen Harvey          34782 Kayla Field\r\nSarahmouth, VT 75984
# 2         Paul Moe                        USNV Mooney\r\nFPO AE 29375
# 3    Sarah Johnson      3633 Bryan Isle\r\nNorth Jamesshire, HI 69484
# 4  Stacy Martinson  65701 Choi Course Apt. 280\r\nNorth Williamton...
#
#   query hyperthyroid FTI measured      education lithium    TT4   T4U  \
# 0                  f            t        HS-grad       f  118.0  1.42
# 1                  f            t        HS-grad       f  112.0  1.03
# 2                  f            t   Some-college       f   87.0  0.96
# 3                  f            t      Doctorate       f  102.0  0.85
# 4                  f            t   Some-college       f  129.0  0.97
#
#    capital-loss  capital-gain ...  hypopituitary  \
# 0           0.0           0.0 ...              f
# 1           0.0           0.0 ...              f
# 2           0.0           0.0 ...              f
# 3           0.0           0.0 ...              f
# 4           0.0           0.0 ...              f
#
#                                         medical_info  \
# 0  {'query hypothyroid':'f','T4U measured':'t','p...
# 1  {'query hypothyroid':'f','T4U measured':'t','p...
# 2  {'query hypothyroid':'f','T4U measured':'t','p...
# 3  {'query hypothyroid':'t','T4U measured':'t','p...
# 4  {'query hypothyroid':'f','T4U measured':'t','p...
#
#    on antithyroid medication  referral source  education-num       occupation  \
# 0                          f            other            9.0     Craft-repair
# 1                      FALSE            other         -900.0     Adm-clerical
# 2                          f              SVI           10.0    Other-service
# 3                          f              SVI           16.0   Prof-specialty
# 4                          F              SVI           10.0    Other-service
#
#   TBG measured TBG    race  FTI
# 0            f   ?   White   83
# 1            f   ?   White  109
# 2            f   ?   White   90
# 3            f   ?   White  119
# 4            f   ?   White  133
#
# [5 rows x 33 columns]

# %%
#Funkcia vráti kľúče v danom dictionary
def dictionary_keys(dictionary):
    if (dictionary == None):
        return None
    keys = []
    
    for key in dictionary:
        key = key
        keys.append(key)
        
    return keys

# %%
#Funkcia vráti hodnoty v danom dictionary
def dictionary_values(dictionary):
    if(dictionary == None):
        return None
    values = []
    
    for key in dictionary:
        val = dictionary[key]
        values.append(val)
        
    return values

# %%
#Funkcia rozparsuje json formát
def parse_medical_info(med_info = None):
    
    if(med_info == None):
        return None
    
    med_info = med_info.strip("{}")  #Odstránime {}
    med_info = med_info.split(",")   #Rozdelime na list podľa ","
    
    new = []
    
    for k in med_info:
        a,b = k.split(":")
        new.append(a.strip("'"))
        new.append(b.strip("'"))
        
    final = dict(new[i:i+2] for i in range(0,len(new),2))
    
    #Návratová hodnota je vytvorený slovník
    return final

# %%
#Funkcia vytvorí nové stĺpce v datasete
def add_columns(data = None, json_col = None):
    
    if (data[json_col].empty or json_col == None):
        return None
    
    #Rozparsujeme si prvý row na dict
    dictionary = parse_medical_info(data[json_col][0])
    keys = dictionary_keys(dictionary)
    
    #Vytvorím si nový dataframe a init na np.Nan
    new = pd.DataFrame(columns=keys,index=range(len(data)))
    
    #Iterácia nad dataframe a parsovanie query
    counter = 0
    for json in data[json_col]:
        try:
            if(np.isnan(json)):
                counter += 1
                new.loc[counter] = np.NaN
                continue
        except:
            pass

        json = parse_medical_info(json)
        new.loc[counter] = dictionary_values(json)
        counter += 1

    
    #Odstránim stĺpce z new a pridám ich do pôvodného
    cols = len(new.columns)
    
    for i in range(cols):
        col = new.pop(new.columns[0])
        name = keys[i]

        data[name] = col
    
    
    #Vrátime rozparsovaný dataframe
    return data

# %%
df_other= add_columns(data=df_other,json_col="medical_info")
df_other[df_other.columns[15:]].head()
# Out:
#      relationship sick workclass TT4 measured  \
# 0         Husband    f   Private            t
# 1   Not-in-family    f       NaN            t
# 2         Husband    f   Private            t
# 3   Not-in-family    f        ??            t
# 4       Own-child    f   Private            t
#
#                              class       marital-status goitre  \
# 0  increased binding protein.|2384   Married-civ-spouse      f
# 1                    negative.|358        Never-married      f
# 2                   negative.|1247   Married-civ-spouse      f
# 3                   negative.|1829        Never-married      f
# 4                   negative.|3531        Never-married      f
#
#    native-country hypopituitary  \
# 0   United-States             f
# 1   United-States             f
# 2   United-States             f
# 3   United-States             f
# 4   United-States             f
#
#                                         medical_info  ...  query hypothyroid  \
# 0  {'query hypothyroid':'f','T4U measured':'t','p...  ...                  f
# 1  {'query hypothyroid':'f','T4U measured':'t','p...  ...                  f
# 2  {'query hypothyroid':'f','T4U measured':'t','p...  ...                  f
# 3  {'query hypothyroid':'t','T4U measured':'t','p...  ...                  t
# 4  {'query hypothyroid':'f','T4U measured':'t','p...  ...                  f
#
#   T4U measured  pregnant thyroid surgery TSH measured query on thyroxine  \
# 0            t         f               f            t                  f
# 1            t         f               f            t                  f
# 2            t         f               f            t                  f
# 3            t         f               f            t                  f
# 4            t         f               f            t                  f
#
#   I131 treatment on thyroxine T3 measured psych
# 0              f            f           t     f
# 1              f            f           t     f
# 2              f            f           t     f
# 3              f            f           t     f
# 4              f            f           t     f
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Unique identifier

# %%
df_personal = pd.read_csv("Datasets/personal_train.csv", index_col=0)
df_personal.head()
# Out:
#                name                                            address   age  \
# 0       Terry Terry  11818 Lori Crossing Apt. 802\r\nPughstad, DC 7...  68.0
# 1   Edith Boudreaux                 PSC 4657, Box 5446\r\nAPO AP 58412  75.0
# 2      Stephen Lalk                 Unit 9759 Box 9470\r\nDPO AP 45549  67.0
# 3     Abraham Bruce  137 Lewis Flat Suite 762\r\nWest Elizabeth, AL...  34.0
# 4  Janet Washington  995 Frank Stravenue\r\nSouth Matthewport, TX 8...  65.0
#
#   sex date_of_birth
# 0   M    1949-11-16
# 1   F    1943-08-10
# 2   M    1951-05-28
# 3   ?    1984-02-13
# 4   F    1953/06/24

# %%
if ( len(df_personal.name.unique()) != len(df_personal.name)):
    print("Found duplicates")
# Out:
# Found duplicates

# %%
#Concatenating name and address
name = df_personal.name.copy() + " " + df_personal.address.copy()

# %%
if(len(name) != len(name.unique())):
    print("Duplicates!")

# %% [markdown]
# ### Other.csv

# %%
df_other = pd.read_csv("Datasets/other_train.csv", index_col=0)
df_other.head()
# Out:
#               name                                            address  \
# 0    John Kasprzak            3856 Kayla Track\r\nLake Sara, HI 31241
# 1   Stephen Harvey          34782 Kayla Field\r\nSarahmouth, VT 75984
# 2         Paul Moe                        USNV Mooney\r\nFPO AE 29375
# 3    Sarah Johnson      3633 Bryan Isle\r\nNorth Jamesshire, HI 69484
# 4  Stacy Martinson  65701 Choi Course Apt. 280\r\nNorth Williamton...
#
#   query hyperthyroid FTI measured      education lithium    TT4   T4U  \
# 0                  f            t        HS-grad       f  118.0  1.42
# 1                  f            t        HS-grad       f  112.0  1.03
# 2                  f            t   Some-college       f   87.0  0.96
# 3                  f            t      Doctorate       f  102.0  0.85
# 4                  f            t   Some-college       f  129.0  0.97
#
#    capital-loss  capital-gain ...  hypopituitary  \
# 0           0.0           0.0 ...              f
# 1           0.0           0.0 ...              f
# 2           0.0           0.0 ...              f
# 3           0.0           0.0 ...              f
# 4           0.0           0.0 ...              f
#
#                                         medical_info  \
# 0  {'query hypothyroid':'f','T4U measured':'t','p...
# 1  {'query hypothyroid':'f','T4U measured':'t','p...
# 2  {'query hypothyroid':'f','T4U measured':'t','p...
# 3  {'query hypothyroid':'t','T4U measured':'t','p...
# 4  {'query hypothyroid':'f','T4U measured':'t','p...
#
#    on antithyroid medication  referral source  education-num       occupation  \
# 0                          f            other            9.0     Craft-repair
# 1                      FALSE            other         -900.0     Adm-clerical
# 2                          f              SVI           10.0    Other-service
# 3                          f              SVI           16.0   Prof-specialty
# 4                          F              SVI           10.0    Other-service
#
#   TBG measured TBG    race  FTI
# 0            f   ?   White   83
# 1            f   ?   White  109
# 2            f   ?   White   90
# 3            f   ?   White  119
# 4            f   ?   White  133
#
# [5 rows x 33 columns]

# %%
other = df_other["name"] + " " + df_other["address"]

# %%
if ( len(df_other.name.unique()) != len(df_other.name)):
    print("Found duplicates")
# Out:
# Found duplicates

# %%
if (len(other) != len(other.unique())):
    print("Still duplicates")
# Out:
# Still duplicates

# %%
#Porovanie df_other a df_personal

# %%
len(df_other.name)
# Out:
# 2287

# %%
other.drop_duplicates()
# Out:
# 0       John Kasprzak 3856 Kayla Track\r\nLake Sara, H...
# 1       Stephen Harvey 34782 Kayla Field\r\nSarahmouth...
# 2                    Paul Moe USNV Mooney\r\nFPO AE 29375
# 3       Sarah Johnson 3633 Bryan Isle\r\nNorth Jamessh...
# 4       Stacy Martinson 65701 Choi Course Apt. 280\r\n...
# 5       Roxanne Benitez 8892 Powell Lock Suite 509\r\n...
# 6       Timothy Selman 74186 Scott Lights\r\nWest Josh...
# 7       Wallace Nicholas 706 Dawn Brooks\r\nWalkerfort...
# 8       Joanne Mcneil 65114 Rodriguez River Suite 382\...
# 9       Wayne Hudgins 1481 Bush Manors Apt. 378\r\nHos...
# 10      Karl Sanchez 9423 Ray Walks Suite 479\r\nLisac...
# 11      Casey Williams 40936 Singh Underpass\r\nRichar...
# 12      Anthony Cates 25324 Mark Points\r\nRussellstad...
# 13      Mary Los 273 Calvin Prairie Apt. 987\r\nEast K...
